# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

points = 500
X = np.linspace(-3, 3, points)
y = np.sin(X) + np.random.uniform(-.5, .5, points)
plt.scatter(X, y)

# %%
model = Sequential()
model.add(Dense(50, input_dim=1, activation="sigmoid"))
model.add(Dense(10,activation="sigmoid"))
model.add(Dense(1))
model.compile(Adam(0.1), loss="mse")

# %%
model.fit(X, y, epochs=50)
# Out:
# Epoch 1/50
# 500/500 [==============================] - 0s 374us/sample - loss: 0.7500
# Epoch 2/50
# 500/500 [==============================] - 0s 56us/sample - loss: 0.2487
# Epoch 3/50
# 500/500 [==============================] - 0s 58us/sample - loss: 0.1582
# Epoch 4/50
# 500/500 [==============================] - 0s 49us/sample - loss: 0.1522
# Epoch 5/50
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1474
# Epoch 6/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1468
# Epoch 7/50
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1438
# Epoch 8/50
# 500/500 [==============================] - 0s 45us/sample - loss: 0.1473
# Epoch 9/50
# 500/500 [==============================] - 0s 57us/sample - loss: 0.1496
# Epoch 10/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1417
# Epoch 11/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1451
# Epoch 12/50
# 500/500 [==============================] - 0s 53us/sample - loss: 0.1502
# Epoch 13/50
# 500/500 [==============================] - 0s 51us/sample - loss: 0.1550
# Epoch 14/50
# 500/500 [==============================] - 0s 55us/sample - loss: 0.1416
# Epoch 15/50
# 500/500 [==============================] - 0s 61us/sample - loss: 0.1451
# Epoch 16/50
# 500/500 [==============================] - 0s 56us/sample - loss: 0.1403
# Epoch 17/50
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1444
# Epoch 18/50
# 500/500 [==============================] - 0s 51us/sample - loss: 0.1601
# Epoch 19/50
# 500/500 [==============================] - 0s 46us/sample - loss: 0.1567
# Epoch 20/50
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1531
# Epoch 21/50
# 500/500 [==============================] - 0s 47us/sample - loss: 0.1556
# Epoch 22/50
# 500/500 [==============================] - 0s 51us/sample - loss: 0.1497
# Epoch 23/50
# 500/500 [==============================] - 0s 50us/sample - loss: 0.1501
# Epoch 24/50
# 500/500 [==============================] - 0s 55us/sample - loss: 0.1406
# Epoch 25/50
# 500/500 [==============================] - 0s 54us/sample - loss: 0.1409
# Epoch 26/50
# 500/500 [==============================] - 0s 54us/sample - loss: 0.1417
# Epoch 27/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1447
# Epoch 28/50
# 500/500 [==============================] - 0s 49us/sample - loss: 0.1562
# Epoch 29/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1355
# Epoch 30/50
# 500/500 [==============================] - 0s 55us/sample - loss: 0.1356
# Epoch 31/50
# 500/500 [==============================] - 0s 55us/sample - loss: 0.1502
# Epoch 32/50
# 500/500 [==============================] - 0s 61us/sample - loss: 0.1378
# Epoch 33/50
# 500/500 [==============================] - 0s 53us/sample - loss: 0.1324
# Epoch 34/50
# 500/500 [==============================] - 0s 56us/sample - loss: 0.1261
# Epoch 35/50
# 500/500 [==============================] - 0s 53us/sample - loss: 0.1213
# Epoch 36/50
# 500/500 [==============================] - 0s 51us/sample - loss: 0.1227
# Epoch 37/50
# 500/500 [==============================] - 0s 54us/sample - loss: 0.1263
# Epoch 38/50
# 500/500 [==============================] - 0s 54us/sample - loss: 0.1242
# Epoch 39/50
# 500/500 [==============================] - 0s 54us/sample - loss: 0.1292
# Epoch 40/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1372
# Epoch 41/50
# 500/500 [==============================] - 0s 55us/sample - loss: 0.1194
# Epoch 42/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1151
# Epoch 43/50
# 500/500 [==============================] - 0s 53us/sample - loss: 0.1196
# Epoch 44/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1183
# Epoch 45/50
# 500/500 [==============================] - 0s 53us/sample - loss: 0.1173
# Epoch 46/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1182
# Epoch 47/50
# 500/500 [==============================] - 0s 57us/sample - loss: 0.1133
# Epoch 48/50
# 500/500 [==============================] - 0s 49us/sample - loss: 0.1194
# Epoch 49/50
# 500/500 [==============================] - 0s 57us/sample - loss: 0.1286
# Epoch 50/50
# 500/500 [==============================] - 0s 52us/sample - loss: 0.1237

# %%
predictions = model.predict(X)
plt.scatter(X, y)
plt.plot(X, predictions, "ro")

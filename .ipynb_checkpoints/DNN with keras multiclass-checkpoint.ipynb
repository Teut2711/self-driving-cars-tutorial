# %%
import numpy as np
import tensorflow.keras as tfk
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt
from sklearn import datasets
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# c:\users\dell\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# c:\users\dell\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# c:\users\dell\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 216, got 192
#   return f(*args, **kwds)
# c:\users\dell\appdata\local\programs\python\python36\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
n_pts = 500
centers = [[-1, 1], [-1, -1], [1, -1]]

# %%
model = tfk.Sequential()
model.add(Dense(units=4, input_shape=(2,), activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))
adam = Adam(lr=.01)
model.compile(adam, loss="binary_crossentropy", metrics=['accuracy']) 
fitted_model = model.fit(x=X, y=y, verbose=1, batch_size=20, epochs=50, shuffle='true')
# Out:
# Train on 500 samples
# Epoch 1/50
# 500/500 [==============================] - 1s 1ms/sample - loss: 0.6373 - accuracy: 0.6880
# Epoch 2/50
# 500/500 [==============================] - 0s 92us/sample - loss: 0.5813 - accuracy: 0.7540
# Epoch 3/50
# 500/500 [==============================] - 0s 84us/sample - loss: 0.5249 - accuracy: 0.8740
# Epoch 4/50
# 500/500 [==============================] - 0s 80us/sample - loss: 0.4631 - accuracy: 0.9240
# Epoch 5/50
# 500/500 [==============================] - 0s 92us/sample - loss: 0.4037 - accuracy: 0.9480
# Epoch 6/50
# 500/500 [==============================] - 0s 94us/sample - loss: 0.3455 - accuracy: 0.9740
# Epoch 7/50
# 500/500 [==============================] - 0s 106us/sample - loss: 0.2913 - accuracy: 0.9920
# Epoch 8/50
# 500/500 [==============================] - 0s 144us/sample - loss: 0.2441 - accuracy: 0.9960
# Epoch 9/50
# 500/500 [==============================] - 0s 100us/sample - loss: 0.2057 - accuracy: 0.9980
# Epoch 10/50
# 500/500 [==============================] - 0s 96us/sample - loss: 0.1750 - accuracy: 0.9980
# Epoch 11/50
# 500/500 [==============================] - 0s 84us/sample - loss: 0.1509 - accuracy: 1.0000
# Epoch 12/50
# 500/500 [==============================] - ETA: 0s - loss: 0.0958 - accuracy: 1.00 - 0s 84us/sample - loss: 0.1310 - accuracy: 1.0000
# Epoch 13/50
# 500/500 [==============================] - 0s 100us/sample - loss: 0.1149 - accuracy: 1.0000
# Epoch 14/50
# 500/500 [==============================] - 0s 92us/sample - loss: 0.1016 - accuracy: 1.0000
# Epoch 15/50
# 500/500 [==============================] - 0s 88us/sample - loss: 0.0906 - accuracy: 1.0000
# Epoch 16/50
# 500/500 [==============================] - 0s 82us/sample - loss: 0.0815 - accuracy: 1.0000
# Epoch 17/50
# 500/500 [==============================] - 0s 82us/sample - loss: 0.0737 - accuracy: 1.0000
# Epoch 18/50
# 500/500 [==============================] - 0s 92us/sample - loss: 0.0668 - accuracy: 1.0000
# Epoch 19/50
# 500/500 [==============================] - 0s 84us/sample - loss: 0.0611 - accuracy: 1.0000
# Epoch 20/50
# 500/500 [==============================] - 0s 78us/sample - loss: 0.0559 - accuracy: 1.0000
# Epoch 21/50
# 500/500 [==============================] - 0s 92us/sample - loss: 0.0514 - accuracy: 1.0000
# Epoch 22/50
# 500/500 [==============================] - 0s 86us/sample - loss: 0.0475 - accuracy: 1.0000
# Epoch 23/50
# 500/500 [==============================] - 0s 96us/sample - loss: 0.0440 - accuracy: 1.0000
# Epoch 24/50
# 500/500 [==============================] - 0s 88us/sample - loss: 0.0409 - accuracy: 1.0000
# Epoch 25/50
# 500/500 [==============================] - 0s 76us/sample - loss: 0.0381 - accuracy: 1.0000
# Epoch 26/50
# 500/500 [==============================] - 0s 90us/sample - loss: 0.0355 - accuracy: 1.0000
# Epoch 27/50
# 500/500 [==============================] - 0s 94us/sample - loss: 0.0333 - accuracy: 1.0000
# Epoch 28/50
# 500/500 [==============================] - 0s 74us/sample - loss: 0.0313 - accuracy: 1.0000
# Epoch 29/50
# 500/500 [==============================] - 0s 84us/sample - loss: 0.0293 - accuracy: 1.0000
# Epoch 30/50
# 500/500 [==============================] - 0s 104us/sample - loss: 0.0276 - accuracy: 1.0000
# Epoch 31/50
# 500/500 [==============================] - 0s 122us/sample - loss: 0.0261 - accuracy: 1.0000
# Epoch 32/50
# 500/500 [==============================] - 0s 98us/sample - loss: 0.0247 - accuracy: 1.0000
# Epoch 33/50
# 500/500 [==============================] - 0s 92us/sample - loss: 0.0234 - accuracy: 1.0000
# Epoch 34/50
# 500/500 [==============================] - 0s 94us/sample - loss: 0.0221 - accuracy: 1.0000
# Epoch 35/50
# 500/500 [==============================] - 0s 100us/sample - loss: 0.0211 - accuracy: 1.0000
# Epoch 36/50
# 500/500 [==============================] - 0s 88us/sample - loss: 0.0200 - accuracy: 1.0000
# Epoch 37/50
# 500/500 [==============================] - 0s 68us/sample - loss: 0.0191 - accuracy: 1.0000
# Epoch 38/50
# 500/500 [==============================] - 0s 88us/sample - loss: 0.0182 - accuracy: 1.0000
# Epoch 39/50
# 500/500 [==============================] - 0s 76us/sample - loss: 0.0174 - accuracy: 1.0000
# Epoch 40/50
# 500/500 [==============================] - 0s 72us/sample - loss: 0.0166 - accuracy: 1.0000
# Epoch 41/50
# 500/500 [==============================] - 0s 74us/sample - loss: 0.0160 - accuracy: 1.0000
# Epoch 42/50
# 500/500 [==============================] - 0s 76us/sample - loss: 0.0153 - accuracy: 1.0000
# Epoch 43/50
# 500/500 [==============================] - 0s 74us/sample - loss: 0.0146 - accuracy: 1.0000
# Epoch 44/50
# 500/500 [==============================] - 0s 76us/sample - loss: 0.0141 - accuracy: 1.0000
# Epoch 45/50
# 500/500 [==============================] - 0s 72us/sample - loss: 0.0135 - accuracy: 1.0000
# Epoch 46/50
# 500/500 [==============================] - 0s 72us/sample - loss: 0.0129 - accuracy: 1.0000
# Epoch 47/50
# 500/500 [==============================] - 0s 82us/sample - loss: 0.0124 - accuracy: 1.0000
# Epoch 48/50
# 500/500 [==============================] - 0s 74us/sample - loss: 0.0119 - accuracy: 1.0000
# Epoch 49/50
# 500/500 [==============================] - 0s 80us/sample - loss: 0.0115 - accuracy: 1.0000
# Epoch 50/50
# 500/500 [==============================] - 0s 74us/sample - loss: 0.0111 - accuracy: 1.0000

# %%
plt.plot(fitted_model.history['accuracy'],"r",fitted_model.history['loss'], "b")
plt.title('accuracy')
plt.xlabel('epoch')
plt.legend(["Accuracy", "Loss"])
plt.show()

# %%
def plot_decision_boundary(X, y, model):
    x_span = np.linspace(min(X[:, 0])-1/4, max(X[:, 0])+1/4, 50)
    y_span = np.linspace(min(X[:, 1])-1/4, max(X[:, 1])+1/4, 50)
    xx, yy = np.meshgrid(x_span, y_span)     
    xx_, yy_ = xx.ravel(), yy.ravel()
    grid = np.c_[xx_, yy_]
    pred_func = model.predict(grid)
    z = pred_func.reshape(xx.shape)
    plt.contourf(xx, yy, z)
    
plot_decision_boundary(X, y, model)    
plt.scatter(X[y==0, 0], X[y==0, 1])
plt.scatter(X[y==1, 0], X[y==1, 1])
prediction = model.predict(np.array([[-.5,.6]]))
print(prediction)
plt.plot(-.5, .6, marker="*",markersize=15,color="red")
# Out:
# [[0.00233611]]
